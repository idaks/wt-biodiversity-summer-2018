# %%
#import the libaries we need to use

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import datetime
import us
# %matplotlib inline

##  Import display 
from IPython.display import display


### ipywidget libraries
from ipywidgets import HBox, VBox, IntSlider, Play, jslink
from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets

### bqplot libraries
import bqplot
from bqplot import (
    Axis, ColorAxis, LinearScale, DateScale, DateColorScale, OrdinalScale, Mercator, Orthographic,
    OrdinalColorScale, ColorScale, Scatter, Lines, Figure, Tooltip, Map, ColorAxis, AlbersUSA, topo_load
)

### seaborn
import seaborn as sns

### basemap
from mpl_toolkits.basemap import Basemap

# %%
#skip the bad lines -> maybe we should do data cleaning first
d1=pd.read_csv("Magnolia/Dataset/geocoded/Magnolia_secWeakley2014_geocoded.csv",error_bad_lines=False)
d2=pd.read_csv("Magnolia/Dataset/geocoded/Magnolia_secChapman1883_geocoded.csv",error_bad_lines=False)
d3=pd.read_csv("Magnolia/Dataset/geocoded/Magnolia_secCronquist1991_geocoded.csv",error_bad_lines=False)
d4=pd.read_csv("Magnolia/Dataset/geocoded/Magnolia_secFNA1997_geocoded.csv",error_bad_lines=False)
d5=pd.read_csv("Magnolia/Dataset/geocoded/Magnolia_secRAB1968_geocoded.csv",error_bad_lines=False)
d6=pd.read_csv("Magnolia/Dataset/geocoded/Magnolia_secSimaLu2012_geocoded.csv",error_bad_lines=False)
d7=pd.read_csv("Magnolia/Dataset/geocoded/Magnolia_secSmall1933_geocoded.csv",error_bad_lines=False)
d8=pd.read_csv("Magnolia/Dataset/geocoded/Magnolia_secSpongberg1998_geocoded.csv",error_bad_lines=False)
d9=pd.read_csv("Magnolia/Dataset/geocoded/Magnolia_secTobe1998_geocoded.csv",error_bad_lines=False)
d10=pd.read_csv("Magnolia/Dataset/geocoded/Magnolia_secWunderlinHansen2011_geocoded.csv",error_bad_lines=False)
# Out:
# b'Skipping line 79: expected 86 fields, saw 87\nSkipping line 257: expected 86 fields, saw 87\nSkipping line 258: expected 86 fields, saw 87\nSkipping line 347: expected 86 fields, saw 87\nSkipping line 353: expected 86 fields, saw 89\nSkipping line 354: expected 86 fields, saw 89\nSkipping line 539: expected 86 fields, saw 87\nSkipping line 545: expected 86 fields, saw 87\nSkipping line 616: expected 86 fields, saw 87\nSkipping line 617: expected 86 fields, saw 87\n'
# b'Skipping line 79: expected 86 fields, saw 87\nSkipping line 257: expected 86 fields, saw 87\nSkipping line 258: expected 86 fields, saw 87\nSkipping line 347: expected 86 fields, saw 87\nSkipping line 353: expected 86 fields, saw 89\nSkipping line 354: expected 86 fields, saw 89\nSkipping line 539: expected 86 fields, saw 87\nSkipping line 545: expected 86 fields, saw 87\nSkipping line 616: expected 86 fields, saw 87\nSkipping line 617: expected 86 fields, saw 87\n'
# ...

# %%
#Weakley 2014
sns.lmplot( x="decimalLongitude", y="decimalLatitude", data=d1, fit_reg=False, hue='scientificName', legend=False, size=10, aspect=1.5)
plt.legend(loc='lower right')
plt.title('Weakley 2014')

m1=Basemap(llcrnrlat = 23.05,
            llcrnrlon = -126.58,
            urcrnrlat = 50.43,
            urcrnrlon = -64.09)
m1.drawmapboundary(fill_color='#A6CAE0', linewidth=0)
m1.fillcontinents(color='grey', alpha=0.3)
m1.drawcoastlines(linewidth=0.1, color="white")

#Chapman 1883
sns.lmplot( x="decimalLongitude", y="decimalLatitude", data=d2, fit_reg=False, hue='scientificName', legend=False, size=10, aspect=1.5)
plt.legend(loc='lower right')
plt.title('Chapman 1883')

m2=Basemap(llcrnrlat = 23.05,
            llcrnrlon = -126.58,
            urcrnrlat = 50.43,
            urcrnrlon = -64.09)
m2.drawmapboundary(fill_color='#A6CAE0', linewidth=0)
m2.fillcontinents(color='grey', alpha=0.3)
m2.drawcoastlines(linewidth=0.1, color="white")

#Cronquist 1991
sns.lmplot( x="decimalLongitude", y="decimalLatitude", data=d3, fit_reg=False, hue='scientificName', legend=False, size=10, aspect=1.5)
plt.legend(loc='lower right')
plt.title('Cronquist 1991')

m3=Basemap(llcrnrlat = 23.05,
            llcrnrlon = -126.58,
            urcrnrlat = 50.43,
            urcrnrlon = -64.09)
m3.drawmapboundary(fill_color='#A6CAE0', linewidth=0)
m3.fillcontinents(color='grey', alpha=0.3)
m3.drawcoastlines(linewidth=0.1, color="white")

#FNA 1997
sns.lmplot( x="decimalLongitude", y="decimalLatitude", data=d4, fit_reg=False, hue='scientificName', legend=False, size=10, aspect=1.5)
plt.legend(loc='lower right')
plt.title('FNA 1997')

m4=Basemap(llcrnrlat = 23.05,
            llcrnrlon = -126.58,
            urcrnrlat = 50.43,
            urcrnrlon = -64.09)
m4.drawmapboundary(fill_color='#A6CAE0', linewidth=0)
m4.fillcontinents(color='grey', alpha=0.3)
m4.drawcoastlines(linewidth=0.1, color="white")
# Out:
# /Users/jessicacheng/anaconda3/lib/python3.6/site-packages/mpl_toolkits/basemap/__init__.py:1698: MatplotlibDeprecationWarning: The axesPatch function was deprecated in version 2.1. Use Axes.patch instead.
#   limb = ax.axesPatch
# /Users/jessicacheng/anaconda3/lib/python3.6/site-packages/mpl_toolkits/basemap/__init__.py:1767: MatplotlibDeprecationWarning: The get_axis_bgcolor function was deprecated in version 2.0. Use get_facecolor instead.
#   axisbgc = ax.get_axis_bgcolor()

# %%
#Weakley 2014
sns.lmplot( x="decimalLongitude", y="decimalLatitude", data=d1, fit_reg=False, hue='scientificName', legend=False, size=10, aspect=1.5)
plt.legend(loc='lower right')
plt.title('Weakley 2014')

m1=Basemap(llcrnrlat = 24.09,
            llcrnrlon = -96.96,
            urcrnrlat = 47.27,
            urcrnrlon = -64.61)
m1.drawmapboundary(fill_color='#A6CAE0', linewidth=0)
m1.fillcontinents(color='grey', alpha=0.3)
m1.drawcoastlines(linewidth=0.1, color="white")

#Chapman 1883
sns.lmplot( x="decimalLongitude", y="decimalLatitude", data=d2, fit_reg=False, hue='scientificName', legend=False, size=10, aspect=1.5)
plt.legend(loc='lower right')
plt.title('Chapman 1883')

m2=Basemap(llcrnrlat = 24.09,
            llcrnrlon = -96.96,
            urcrnrlat = 47.27,
            urcrnrlon = -64.61)
m2.drawmapboundary(fill_color='#A6CAE0', linewidth=0)
m2.fillcontinents(color='grey', alpha=0.3)
m2.drawcoastlines(linewidth=0.1, color="white")

#Cronquist 1991
sns.lmplot( x="decimalLongitude", y="decimalLatitude", data=d3, fit_reg=False, hue='scientificName', legend=False, size=10, aspect=1.5)
plt.legend(loc='lower right')
plt.title('Cronquist 1991')

m3=Basemap(llcrnrlat = 24.09,
            llcrnrlon = -96.96,
            urcrnrlat = 47.27,
            urcrnrlon = -64.61)
m3.drawmapboundary(fill_color='#A6CAE0', linewidth=0)
m3.fillcontinents(color='grey', alpha=0.3)
m3.drawcoastlines(linewidth=0.1, color="white")

#FNA 1997
sns.lmplot( x="decimalLongitude", y="decimalLatitude", data=d4, fit_reg=False, hue='scientificName', legend=False, size=10, aspect=1.5)
plt.legend(loc='lower right')
plt.title('FNA 1997')

m4=Basemap(llcrnrlat = 24.09,
            llcrnrlon = -96.96,
            urcrnrlat = 47.27,
            urcrnrlon = -64.61)
m4.drawmapboundary(fill_color='#A6CAE0', linewidth=0)
m4.fillcontinents(color='grey', alpha=0.3)
m4.drawcoastlines(linewidth=0.1, color="white")
# Out:
# /Users/jessicacheng/anaconda3/lib/python3.6/site-packages/mpl_toolkits/basemap/__init__.py:1698: MatplotlibDeprecationWarning: The axesPatch function was deprecated in version 2.1. Use Axes.patch instead.
#   limb = ax.axesPatch
# /Users/jessicacheng/anaconda3/lib/python3.6/site-packages/mpl_toolkits/basemap/__init__.py:1767: MatplotlibDeprecationWarning: The get_axis_bgcolor function was deprecated in version 2.0. Use get_facecolor instead.
#   axisbgc = ax.get_axis_bgcolor()

# %%
#d= dataset, t= taxonomy name
def plotdata(d,t):
    sns.lmplot( x="decimalLongitude", y="decimalLatitude", data=d, fit_reg=False, hue='scientificName', legend=False, size=10, aspect=1.5)
    plt.legend(loc='lower right')
    plt.title(t)
    m=Basemap(llcrnrlat = 24.09,
            llcrnrlon = -96.96,
            urcrnrlat = 47.27,
            urcrnrlon = -64.61)
    m.drawmapboundary(fill_color='#A6CAE0', linewidth=0)
    m.fillcontinents(color='grey', alpha=0.3)
    m.drawcoastlines(linewidth=0.1, color="white")
    plt.savefig(t, bbox_inches='tight')

# %%
d1=pd.read_csv("Magnolia/Dataset/geocoded/Magnolia_secWeakley2014_geocoded.csv",error_bad_lines=False)
d2=pd.read_csv("Magnolia/Dataset/geocoded/Magnolia_secChapman1883_geocoded.csv",error_bad_lines=False)
# Out:
# b'Skipping line 79: expected 86 fields, saw 87\nSkipping line 257: expected 86 fields, saw 87\nSkipping line 258: expected 86 fields, saw 87\nSkipping line 347: expected 86 fields, saw 87\nSkipping line 353: expected 86 fields, saw 89\nSkipping line 354: expected 86 fields, saw 89\nSkipping line 539: expected 86 fields, saw 87\nSkipping line 545: expected 86 fields, saw 87\nSkipping line 616: expected 86 fields, saw 87\nSkipping line 617: expected 86 fields, saw 87\n'
# b'Skipping line 79: expected 86 fields, saw 87\nSkipping line 257: expected 86 fields, saw 87\nSkipping line 258: expected 86 fields, saw 87\nSkipping line 347: expected 86 fields, saw 87\nSkipping line 353: expected 86 fields, saw 89\nSkipping line 354: expected 86 fields, saw 89\nSkipping line 539: expected 86 fields, saw 87\nSkipping line 545: expected 86 fields, saw 87\nSkipping line 616: expected 86 fields, saw 87\nSkipping line 617: expected 86 fields, saw 87\n'

# %%
plotdata(d1,'Weakley 2014')
plotdata(d2,'Chapman 1883')
# Out:
# /Users/jessicacheng/anaconda3/lib/python3.6/site-packages/mpl_toolkits/basemap/__init__.py:1698: MatplotlibDeprecationWarning: The axesPatch function was deprecated in version 2.1. Use Axes.patch instead.
#   limb = ax.axesPatch
# /Users/jessicacheng/anaconda3/lib/python3.6/site-packages/mpl_toolkits/basemap/__init__.py:1767: MatplotlibDeprecationWarning: The get_axis_bgcolor function was deprecated in version 2.0. Use get_facecolor instead.
#   axisbgc = ax.get_axis_bgcolor()

# %%
import matplotlib.image as mpimg
img1=mpimg.imread('Weakley 2014.png')
img2=mpimg.imread('Chapman 1883.png')
img3=mpimg.imread('Magnolia2014_1883.png')

plt.figure(figsize=(30,30))
ax1=plt.subplot(221)
ax1.axis('off')
plt.imshow(img1)

ax2=plt.subplot(222)
ax2.axis('off')
plt.imshow(img2)

ax1=plt.subplot(212)
ax1.axis('off')
plt.imshow(img3)

plt.tight_layout()

plt.savefig('comparison2014_1883', bbox_inches='tight')
